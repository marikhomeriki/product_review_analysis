# %%
# stanfordnlp.download('en')
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer 
import stanza


def aspect_sentiment_analysis(txt, stop_words, nlp):
    
    txt = txt.lower() # LowerCasing the given Text
    sentList = nltk.sent_tokenize(txt) # Splitting the text into sentences

    fcluster = []
    totalfeatureList = []
    finalcluster = []
    dic = {}

    for line in sentList:
        newtaggedList = []
        txt_list = nltk.word_tokenize(line) # Splitting up into words
        taggedList = nltk.pos_tag(txt_list) # Doing Part-of-Speech Tagging to each word

        newwordList = []
        flag = 0
        for i in range(0,len(taggedList)-1):
            if(taggedList[i][1]=="NN" and taggedList[i+1][1]=="NN"): # If two consecutive words are Nouns then they are joined together
                newwordList.append(taggedList[i][0]+taggedList[i+1][0])
                flag=1
            else:
                if(flag==1):
                    flag=0
                    continue
                newwordList.append(taggedList[i][0])
                if(i==len(taggedList)-2):
                    newwordList.append(taggedList[i+1][0])

        finaltxt = ' '.join(word for word in newwordList) 
        new_txt_list = nltk.word_tokenize(finaltxt)
        wordsList = [w for w in new_txt_list if not w in stop_words]
        taggedList = nltk.pos_tag(wordsList)

        doc = nlp(finaltxt) # Object of Stanford NLP Pipeleine
        
        # Getting the dependency relations betwwen the words
        dep_node = []
        for dep_edge in doc.sentences[0].dependencies:
            print(dep_edge)
            dep_node.append([dep_edge[2].text, dep_edge[0].index, dep_edge[1]])

        # Coverting it into appropriate format
        for i in range(0, len(dep_node)):
            if (int(dep_node[i][1]) != 0):
                dep_node[i][1] = newwordList[(int(dep_node[i][1]) - 1)]

        featureList = []
        categories = []
        for i in taggedList:
            if(i[1]=='JJ' or i[1]=='NN' or i[1]=='JJR' or i[1]=='NNS' or i[1]=='RB'):
                featureList.append(list(i)) # For features for each sentence
                totalfeatureList.append(list(i)) # Stores the features of all the sentences in the text
                categories.append(i[0])

        for i in featureList:
            filist = []
            for j in dep_node:
                if((j[0]==i[0] or j[1]==i[0]) and (j[2] in ["nsubj", "acl:relcl", "obj", "dobj", "agent", "advmod", "amod", "neg", "prep_of", "acomp", "xcomp", "compound"])):
                    if(j[0]==i[0]):
                        filist.append(j[1])
                    else:
                        filist.append(j[0])
            fcluster.append([i[0], filist])
            
    for i in totalfeatureList:
        dic[i[0]] = i[1]
    
    for i in fcluster:
        if(dic[i[0]]=="NN"):
            finalcluster.append(i)
        
    return(finalcluster)

nlp = stanza.Pipeline()
stop_words = set(stopwords.words('english'))
txt = "The Sound Quality is great but the battery life is very bad."

aspect_sentiment_analysis(txt, stop_words, nlp)

# Output: [['soundquality', ['great']], ['batterylife', ['bad']]]
# Out:
# 2022-12-01 10:39:41 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 78.2MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/tokenize/combined.pt: 100%|███████████████████████████████████████████████████████████████| 647k/647k [00:00<00:00, 2.24MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pos/combined.pt: 100%|███████████████████████████████████████████████████████████████████| 38.5M/38.5M [00:39<00:00, 975kB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/lemma/combined.pt: 100%|████████████████████████████████████████████████████████████████| 4.17M/4.17M [00:00<00:00, 4.31MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/depparse/combined.pt: 100%|███████████████████████████████████████████████████████████████| 109M/109M [00:34<00:00, 3.21MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/sentiment/sstplus.pt: 100%|█████████████████████████████████████████████████████████████| 80.4M/80.4M [00:31<00:00, 2.58MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/constituency/wsj.pt: 100%|████████████████████████████████████████████████████████████████| 113M/113M [00:40<00:00, 2.81MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/ner/ontonotes.pt: 100%|█████████████████████████████████████████████████████████████████| 46.2M/46.2M [00:10<00:00, 4.45MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pretrain/combined.pt: 100%|███████████████████████████████████████████████████████████████| 107M/107M [00:35<00:00, 3.02MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/forward_charlm/1billion.pt: 100%|███████████████████████████████████████████████████████| 22.7M/22.7M [00:07<00:00, 3.14MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/pretrain/fasttextcrawl.pt: 100%|██████████████████████████████████████████████████████████| 123M/123M [00:45<00:00, 2.68MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/backward_charlm/1billion.pt: 100%|██████████████████████████████████████████████████████| 22.7M/22.7M [00:09<00:00, 2.42MB/s]
# 2022-12-01 10:44:06 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-12-01 10:44:06 INFO: Use device: cpu
# 2022-12-01 10:44:06 INFO: Loading: tokenize
# 2022-12-01 10:44:06 INFO: Loading: pos
# 2022-12-01 10:44:07 INFO: Loading: lemma
# 2022-12-01 10:44:07 INFO: Loading: depparse
# 2022-12-01 10:44:07 INFO: Loading: sentiment
# 2022-12-01 10:44:07 INFO: Loading: constituency
# 2022-12-01 10:44:08 INFO: Loading: ner
# 2022-12-01 10:44:09 INFO: Done loading processors!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [19], line 93
#      90 stop_words = set(stopwords.words('english'))
#      91 txt = "The Sound Quality is great but the battery life is very bad."
# ---> 93 aspect_sentiment_analysis(txt, stop_words, nlp)
#      95 # Output: [['soundquality', ['great']], ['batterylife', ['bad']]]
#
# Cell In [19], line 55, in aspect_sentiment_analysis(txt, stop_words, nlp)
#      53 dep_node = []
#      54 for dep_edge in doc.sentences[0].dependencies:
# ---> 55     dep_node.append([dep_edge[2].text, dep_edge[0].index, dep_edge[1]])
#      57 # Coverting it into appropriate format
#      58 for i in range(0, len(dep_node)):
#
# AttributeError: 'Word' object has no attribute 'index'
