# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

# %%
print("hello world")
# Out:
# hello world

# %%
# variable declaration
customer_review = {}
url = ""

# %%
# while not url:
#     url = input("Enter your URL: ")
url = "https://www.yelp.co.uk/biz/dishoom-london"

# %%
# page_numbers = int(input("Pages of reviews to include: "))
page_numbers = 20

# %%
for i in range(0,page_numbers*10,10):
    page = url + f"?start={i}"
    response = requests.get(page)
    time.sleep(1)
    soup = BeautifulSoup(response.content, "html.parser")
    reviews = soup.find_all("div", class_ = "review__09f24__oHr9V")
    for j,review in enumerate(reviews):
        text = review.find("p", class_="comment__09f24__gu0rG").find("span", class_="raw__09f24__T4Ezm").get_text()
        review_rating = review.find("div", class_="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")["aria-label"]
        customer_review[f"review_{j+i}"] = text
        customer_review[f"score_{j+i}"] = review_rating

# %%
customer_review
# Out:
# {'review_0': "Hundreds of happy customers come through every hour. \xa0Don't let the outdoor queue scare you off as it did me last night but I came back for lunch today and the line, albeit the length of the restaurant, only took 20 minutes or less. \xa0All the employees were very courteous and pleasant.The chicken ruby was just amazing and very complex. There was not a drop left. The paneer tikka is probably meant to be shared \xa0and was a bit underwhelming. \xa0We got a downstairs table near the bar and dishwasher so it was terribly noisy with all the silverware. \xa0But, it was also indicative just how popular this place is.",
#  'score_0': '5 star rating',
# ...

# %%
df_reviews = pd.DataFrame([(customer_review[f"review_{i}"],customer_review[f"score_{i}"])for i in range(int(len(customer_review)/2))])
df_reviews.columns = ["Review", "Score"]
df_reviews["Score"] = df_reviews.Score.str.replace("star rating", "")
df_reviews
# Out:
#                                                 Review Score
# 0    Hundreds of happy customers come through every...    5
# 1    We came for breakfast on a Monday so we were a...    4
# 2    Have been wanting to go to Dishoom for years a...    4
# 3    The best Indian food in London!This is my 3rd ...    5
# 4    I'm sure there's not much more I could say bec...    5
# ..                                                 ...   ...
# 195  Came for brunch and was very impressed with th...    5
# 196  Great food.  Small plates were delicious.  Fri...    3
# 197  Found Dishoom during a trip to London and deci...    5
# 198  Ok, I don't really fancy Indian food but my go...    4
# 199  Always delicious and a great dining experience...    5
#
# [200 rows x 2 columns]

# %%
df_reviews.to_csv('../../reviews.csv')

# %%
import time
url = "https://www.yelp.co.uk/biz/dishoom-london"
soup = BeautifulSoup(response.content, "html.parser")
reviews = soup.find_all("div", class_ = "review__09f24__oHr9V")
x = {}

pages = []
for i in range(0,50,10):
    time.sleep(1)
    page = url + f"?start={i}"
    response = requests.get(page)
    soup = BeautifulSoup(response.content, "html.parser")
    pages.append(soup)

# %%
len(pages)
# Out:
# 5

# %%
review_texts = []
for review in pages[0].find_all("p", class_="comment__09f24__gu0rG"):
    review_texts.append(review.find("span", class_="raw__09f24__T4Ezm").get_text())
review_texts
# Out:
# ["the most authentic Indian restaurant in London by far. Every dish we had was amazing and reminded me of my home country. Also the atmosphere and vibe is real special. I've gone countless times and have never had a bad meal of substandard service..",
#  "Hundreds of happy customers come through every hour. \xa0Don't let the outdoor queue scare you off as it did me last night but I came back for lunch today and the line, albeit the length of the restaurant, only took 20 minutes or less. \xa0All the employees were very courteous and pleasant.The chicken ruby was just amazing and very complex. There was not a drop left. The paneer tikka is probably meant to be shared \xa0and was a bit underwhelming. \xa0We got a downstairs table near the bar and dishwasher so it was terribly noisy with all the silverware. \xa0But, it was also indicative just how popular this place is.",
# ...

# %%
len(pages[0].find_all("div", class_="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"))
# Out:
# 20

# %%
review_texts = []
review_scores = []
for k,review in enumerate(pages):
    
    for review_text in review.find_all("p", class_="comment__09f24__gu0rG"):
        review_texts.append(review_text.find("span", class_="raw__09f24__T4Ezm").get_text())
        
    for review_rating in review.find_all("div", class_="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"):
        review_scores.append(review_rating)

len(review_texts),len(review_scores)
# Out:
# (51, 101)

# %%
review_scores
# Out:
# [<div aria-label="5 star rating" class="five-stars__09f24__mBKym five-stars--regular__09f24__DgBNj display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY" role="img"><div class="star__09f24__YoVH5 star--regular__09f24__IopbI display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY"><svg height="20" viewbox="0 0 20 20" width="20"><path d="M0 4C0 1.79086 1.79086 0 4 0H10V20H4C1.79086 20 0 18.2091 0 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path d="M20 4C20 1.79086 18.2091 0 16 0H10V20H16C18.2091 20 20 18.2091 20 16V4Z" fill="rgba(251,67,60,1)" opacity="1"></path><path clip-rule="evenodd" d="M10 13.3736L12.5949 14.7111C12.7378 14.7848 12.9006 14.8106 13.0593 14.7847C13.4681 14.718 13.7454 14.3325 13.6787 13.9237L13.2085 11.0425L15.2824 8.98796C15.3967 8.8748 15.4715 8.72792 15.4959 8.569C15.5588 8.15958 15.2779 7.77672 14.8685 7.71384L11.983 7.2707L10.6699 4.66338C10.5975 4.51978 10.481 4.40322 10.3374 4.33089C9.96742 4.14458 9.51648 4.29344 9.3
# ...

# %%
df_reviews = pd.DataFrame([(x[f"review_{i}"],x[f"score_{i}"])for i in range(5)])
df_reviews.columns = ["Review", "Score"]
df_reviews["Score"] = df_reviews.Score.str.replace("star rating", "")
df_reviews
# Out:
#                                               Review Score
# 0  the most authentic Indian restaurant in London...    5
# 1  the most authentic Indian restaurant in London...    5
# 2  the most authentic Indian restaurant in London...    5
# 3  the most authentic Indian restaurant in London...    5
# 4  the most authentic Indian restaurant in London...    5
